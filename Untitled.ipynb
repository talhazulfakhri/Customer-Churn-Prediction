# %%
# Import necessary libraries
import streamlit as st
import pandas as pd
import plotly.graph_objects as go
import joblib

# Load your pre-trained model (if you have one saved as 'model.pkl')
# Uncomment the line below if you have a model
# model = joblib.load('model.pkl')

# Load dataset (assuming you have a CSV file with your data)
@st.cache  # Cache the data to make the app faster
def load_data():
    data = pd.read_csv('Telco Customer Churn.csv')
    return data

data = load_data()

# Sidebar for user input parameters
st.sidebar.header("Customer Input Parameters")

# Function to get user input
def user_input_features():
    gender = st.sidebar.selectbox("Gender", ("Male", "Female"))
    SeniorCitizen = st.sidebar.selectbox("Senior Citizen", (0, 1))
    Partner = st.sidebar.selectbox("Partner", ("Yes", "No"))
    Dependents = st.sidebar.selectbox("Dependents", ("Yes", "No"))
    tenure = st.sidebar.slider("Tenure (Months)", 0, 72, 12)
    MonthlyCharges = st.sidebar.slider("Monthly Charges", 10.0, 150.0, 70.0)
    TotalCharges = st.sidebar.slider("Total Charges", 0.0, 8000.0, 2000.0)
    data = {
        'gender': gender,
        'SeniorCitizen': SeniorCitizen,
        'Partner': Partner,
        'Dependents': Dependents,
        'tenure': tenure,
        'MonthlyCharges': MonthlyCharges,
        'TotalCharges': TotalCharges
    }
    features = pd.DataFrame(data, index=[0])
    return features

input_df = user_input_features()

# Display the main title and introduction
st.title("Customer Churn Prediction App")
st.write("""
This app predicts whether a customer will churn based on demographic and account information. Use the sidebar to input customer details.
""")

# Show the dataset
if st.checkbox("Show Raw Data"):
    st.write(data.head())

# Visualizations for Gender and Churn distributions
st.subheader("Gender Distribution")
gender_counts = data['gender'].value_counts()
fig_gender = go.Figure(data=[go.Pie(labels=gender_counts.index, values=gender_counts.values, hole=0.4)])
fig_gender.update_layout(title_text="Gender Distribution")
st.plotly_chart(fig_gender)

st.subheader("Churn Distribution")
churn_counts = data['Churn'].value_counts()
fig_churn = go.Figure(data=[go.Pie(labels=churn_counts.index, values=churn_counts.values, hole=0.4)])
fig_churn.update_layout(title_text="Churn Distribution")
st.plotly_chart(fig_churn)

# Model Prediction (if a model is available)
st.subheader("Predict Churn")

# Uncomment the following lines if you have a trained model (model.pkl)
# if st.button("Predict Churn"):
#     prediction = model.predict(input_df)[0]
#     prediction_proba = model.predict_proba(input_df)[0][1]
#     st.write(f"Prediction: {'Churn' if prediction == 1 else 'No Churn'}")
#     st.write(f"Churn Probability: {prediction_proba:.2f}")
# Out:
# 2024-11-01 22:07:46.775 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.155
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run T:\Anaconda\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-01 22:07:47.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.156
# `st.cache` is deprecated and will be removed soon. Please use one of Streamlit's new
# caching commands, `st.cache_data` or `st.cache_resource`. More information
# [in our docs](https://docs.streamlit.io/develop/concepts/architecture/caching).
#
# **Note**: The behavior of `st.cache` was updated in Streamlit 1.36 to the new caching
# logic used by `st.cache_data` and `st.cache_resource`. This might lead to some problems
# or unexpected behavior in certain edge cases.
#
# 2024-11-01 22:07:47.157 No runtime found, using MemoryCacheStorageManager
# 2024-11-01 22:07:47.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.161 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.163 No runtime found, using MemoryCacheStorageManager
# 2024-11-01 22:07:47.191 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.195 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.196 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.197 Session state does not function when running a script without `streamlit run`
# 2024-11-01 22:07:47.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.200 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.203 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.208 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.211 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.212 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.214 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.219 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.222 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.225 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.227 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.228 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.234 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.235 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.241 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.297 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.299 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-01 22:07:47.300 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Using cached streamlit-1.39.0-py2.py3-none-any.whl (8.7 MB)
# Collecting pydeck<1,>=0.8.0b4
#   Using cached pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
# Collecting typing-extensions<5,>=4.3.0
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Collecting altair<6,>=4.0
#   Using cached altair-5.4.1-py3-none-any.whl (658 kB)
# Requirement already satisfied: watchdog<6,>=2.1.5 in t:\anaconda\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: pillow<11,>=7.1.0 in t:\anaconda\lib\site-packages (from streamlit) (9.0.1)
# Requirement already satisfied: numpy<3,>=1.20 in t:\anaconda\lib\site-packages (from streamlit) (1.21.5)
# Collecting pyarrow>=7.0
#   Using cached pyarrow-18.0.0-cp39-cp39-win_amd64.whl (25.1 MB)
# Collecting gitpython!=3.1.19,<4,>=3.0.7
#   Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Collecting tenacity<10,>=8.1.0
#   Using cached tenacity-9.0.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: pandas<3,>=1.4.0 in t:\anaconda\lib\site-packages (from streamlit) (1.4.4)
# Requirement already satisfied: requests<3,>=2.27 in t:\anaconda\lib\site-packages (from streamlit) (2.27.1)
# Collecting rich<14,>=10.14.0
#   Using cached rich-13.9.3-py3-none-any.whl (242 kB)
# Collecting protobuf<6,>=3.20
#   Using cached protobuf-5.28.3-cp39-cp39-win_amd64.whl (431 kB)
# Requirement already satisfied: click<9,>=7.0 in t:\anaconda\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: cachetools<6,>=4.0 in t:\anaconda\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: tornado<7,>=6.0.3 in t:\anaconda\lib\site-packages (from streamlit) (6.1)
# Requirement already satisfied: packaging<25,>=20 in t:\anaconda\lib\site-packages (from streamlit) (21.3)
# Collecting blinker<2,>=1.0.0
#   Using cached blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: toml<2,>=0.10.1 in t:\anaconda\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: jsonschema>=3.0 in t:\anaconda\lib\site-packages (from altair<6,>=4.0->streamlit) (4.4.0)
# Collecting narwhals>=1.5.2
#   Using cached narwhals-1.12.1-py3-none-any.whl (195 kB)
# Requirement already satisfied: jinja2 in t:\anaconda\lib\site-packages (from altair<6,>=4.0->streamlit) (2.11.3)
# Requirement already satisfied: colorama in t:\anaconda\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.4)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: attrs>=17.4.0 in t:\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in t:\anaconda\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in t:\anaconda\lib\site-packages (from packaging<25,>=20->streamlit) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in t:\anaconda\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in t:\anaconda\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2021.3)
# Requirement already satisfied: MarkupSafe>=0.23 in t:\anaconda\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.0.1)
# Requirement already satisfied: six>=1.5 in t:\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in t:\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in t:\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in t:\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in t:\anaconda\lib\site-packages (from requests<3,>=2.27->streamlit) (2.0.4)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\talha\appdata\roaming\python\python39\site-packages (from rich<14,>=10.14.0->streamlit) (2.14.0)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: smmap, mdurl, typing-extensions, narwhals, markdown-it-py, gitdb, tenacity, rich, pydeck, pyarrow, protobuf, gitpython, blinker, altair, streamlit
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.1
#     Uninstalling protobuf-3.19.1:
#       Successfully uninstalled protobuf-3.19.1
# Successfully installed altair-5.4.1 blinker-1.8.2 gitdb-4.0.11 gitpython-3.1.43 markdown-it-py-3.0.0 mdurl-0.1.2 narwhals-1.12.1 protobuf-5.28.3 pyarrow-18.0.0 pydeck-0.9.1 rich-13.9.3 smmap-5.0.1 streamlit-1.39.0 tenacity-9.0.0 typing-extensions-4.12.2
